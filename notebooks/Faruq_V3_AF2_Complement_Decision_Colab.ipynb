# %% [markdown]
# # AF2 complementary mechanisms — seed-42 decision
# Jalankan hanya setelah keempat arm selesai. Tidak melakukan training atau membuka test.

# %%
from google.colab import drive
drive.mount('/content/drive')
import importlib,json,os,shutil,subprocess,sys
from pathlib import Path
REPO=Path('/content/coffee-bean-detection'); BRANCH='codex/af2-complementary-mechanisms'
os.chdir('/content')
if REPO.exists(): shutil.rmtree(REPO)
subprocess.run(['git','clone','--depth','1','--branch',BRANCH,'https://github.com/ediprin/coffee-bean-detection.git',str(REPO)],check=True)
subprocess.run([sys.executable,'-m','pip','install','-q','-e',str(REPO)],check=True)
sys.path.insert(0,str(REPO/'src')); importlib.invalidate_caches(); os.chdir(REPO)
from coffee_detector.drive_project import resolve_drive_project_root
PROJECT=resolve_drive_project_root()
OUTPUT=PROJECT/'experiments/faruq-v3-af2-complement-v1'
SUMMARY=OUTPUT/'val_reports/af2_complement_seed42_decision.json'
command=[sys.executable,'-u','-m','coffee_detector.experiments.run_faruq_v3_af2_complement_decision','--output-root',str(OUTPUT),'--output',str(SUMMARY)]
subprocess.run(command,cwd=REPO,check=True)
print(json.dumps(json.loads(SUMMARY.read_text()),indent=2,ensure_ascii=False))
