# %% [markdown]
# # Coffee Standard J25 — AF2 direct seed-42 decision
# Jalankan setelah D0DIRECT dan AF2DIRECT selesai. Tidak training dan tidak membuka test.

# %%
from google.colab import drive
drive.mount('/content/drive')
import importlib, json, os, shutil, subprocess, sys
from pathlib import Path
REPO=Path('/content/coffee-bean-detection'); BRANCH='codex/coffee-standard-primary-audit'
os.chdir('/content')
if REPO.exists(): shutil.rmtree(REPO)
subprocess.run(['git','clone','--depth','1','--branch',BRANCH,'https://github.com/ediprin/coffee-bean-detection.git',str(REPO)],check=True)
subprocess.run([sys.executable,'-m','pip','install','-q','--no-deps','-e',str(REPO)],check=True)
sys.path.insert(0,str(REPO/'src')); importlib.invalidate_caches(); os.chdir(REPO)
from coffee_detector.drive_project import resolve_drive_project_root
PROJECT=resolve_drive_project_root()
OUT=PROJECT/'experiments/coffee-standard-j25-af2-direct-v1'
from coffee_detector.experiments.run_coffee_standard_j25_af2_direct import build_decision
SUMMARY=OUT/'coffee_standard_j25_af2_direct_seed42_summary.json'
result=build_decision(OUT,SUMMARY)
print('VALUES:',result['values'])
print('DELTAS:',result['deltas'])
print('CRITERIA:',result['criteria'])
print('DECISION:',result['decision'])
print('TEST:',result['test_opened'])
print('SUMMARY:',SUMMARY)
print('Kirim values, deltas, criteria, dan decision. Jangan buka test.')
